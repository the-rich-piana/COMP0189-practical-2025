# %% [markdown]
# # Week 3 - Linear Models and Efficient Computation with Kernels
#
# ## 🎯 Learning goals
#
# 1. Understand how kernel methods enable efficient computation for problems with more features than samples
#
# 2. Apply precomputed kernels using sklearn to solve a practical problem: perform brain decoding using functional Magnetic Images (fMRI) data
#
# 3. Understand the relationship between to the primal and dual formulations in kernel methods
#
# 4. Learn how to work with functional Magnetic Ressonance Imaging (fMRI) data. For information about fMRI check: https://en.wikipedia.org/wiki/Functional_magnetic_resonance_imaging
#
# ### Most common use case of Kernels
# Kernels can help machine learning models learn nonlinear decision boundaries by mapping input data into a higher dimensional feature space. This allows algorithms like support vector machines (SVMs) to find nonlinear boundaries in the input space to classify data. However, using kernels can be also a computational efficient way to train kernel models (e.g. SVMs) when the number of features is higher than the sample size.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 📍 Haxby fMRI dataset
#
# - The Haxby study investigated face and object representation in human ventral temporal cortex
# - The study consisted of 6 subjects passively viewing greyscale images of eight object categories (eg houses, cats, faces), grouped in 24s blocks separated by rest periods
# - The study showed the images for 500ms and was followed by a 1500ms inter-stimulus interval, whilst taking a full-brain fMRI.
# - The machine learning task is to predict the object the sujects was looking at from their pattern of brain activation captured in the fMRI images. This is also known as **brain decoding**.
# - More information can be found in the original study: Haxby, J., Gobbini, M., Furey, M., Ishai, A., Schouten, J., and Pietrini, P. (2001). Distributed and overlapping representations of faces and objects in ventral temporal cortex. Science 293, 2425–2430: https://www.science.org/doi/10.1126/science.1063736

# %% [markdown]
# ### Downloading dataset
#
# We will use `nilearn` a python wrapper around `scikit-learn` that provides useful visualisation and statistical, ML tools for brain volume analysis.
#
# The `nilearn.datasets.fetch_haxby` function will download the Haxby dataset if not present on the disk, in the nilearn data directory. It can take a while to download about 310 MB of data from the Internet.

# %%
# ! pip install nilearn
# Out:
# Collecting nilearn
#   Downloading nilearn-0.11.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (1.4.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from nilearn) (5.3.0)
# Requirement already satisfied: nibabel>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (5.3.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from nilearn) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from nilearn) (24.2)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (2.2.2)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (1.6.1)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from nilearn) (1.13.1)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel>=5.2.0->nilearn) (6.5.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel>=5.2.0->nilearn) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->nilearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->nilearn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.2.0->nilearn) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->nilearn) (2024.12.14)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.0->nilearn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.17.0)
# Downloading nilearn-0.11.1-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 25.1 MB/s eta 0:00:00
# Installing collected packages: nilearn
# Successfully installed nilearn-0.11.1

# %%
from nilearn import datasets

# Fetch Haxby dataset with stimuli
# By default 2nd subject will be fetched
haxby_dataset = datasets.fetch_haxby(fetch_stimuli=True)

# 'func' is a list of filenames: one for each subject
fmri_filename = haxby_dataset.func[0]

# print basic information on the dataset
print(f"First subject functional nifti images (4D) are at: {fmri_filename}")
# Out:
# [get_dataset_dir] Dataset found in C:\Users\Gugu\nilearn_data\haxby2001
# [fetch_single_file] Downloading data from http://data.pymvpa.org/datasets/haxby2001/stimuli-2010.01.14.tar.gz ...
# Downloaded 221184 of 10463676 bytes (2.1%%,   47.8s remaining)
# Downloaded 581632 of 10463676 bytes (5.6%%,   35.0s remaining)
# Downloaded 942080 of 10463676 bytes (9.0%%,   31.6s remaining)
# Downloaded 1392640 of 10463676 bytes (13.3%%,   27.3s remaining)
# Downloaded 1449984 of 10463676 bytes (13.9%%,   32.4s remaining)
# Downloaded 1613824 of 10463676 bytes (15.4%%,   35.2s remaining)
# Downloaded 1728512 of 10463676 bytes (16.5%%,   37.7s remaining)
# Downloaded 10289152 of 10463676 bytes (98.3%%,    0.9s remaining)
# [fetch_single_file]  ...done. (59 seconds, 0 min)
#
# [uncompress_file] Extracting data from C:\Users\Gugu\nilearn_data\haxby2001\b1f16a7309e6e25041031277341050df\stimuli-2010.01.14.tar.gz...
# [uncompress_file] .. done.
#
# First subject functional nifti images (4D) are at: C:\Users\Gugu\nilearn_data\haxby2001\subj2\bold.nii.gz

# %% [markdown]
# ### Visualizing the fMRI volume
#
# One way to visualize a fMRI volume is using `nilearn.plotting.plot_epi.` We will visualize the previously fetched fMRI data from Haxby dataset.
#
# Because fMRI data are 4D (they consist of many 3D EPI images), we cannot plot them directly using nilearn.plotting.plot_epi (which accepts just 3D input). Here we are using `nilearn.image.mean_img` to extract a single 3D EPI image from the fMRI data.

# %% [markdown]
# > Note: the plot is interactive, so you can scroll through the brain and look at different slices!

# %%
from nilearn import plotting
from nilearn.image import mean_img
import warnings
warnings.filterwarnings('ignore')

# Inspect volume dimensionlity (size of image)
print(f'Mean image dimensionality {mean_img(fmri_filename).shape}')

# Plot an fMRI volume
plotting.view_img(mean_img(fmri_filename), threshold=None)
# Out:
# Mean image dimensionality (40, 64, 64)
# <iframe srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;div_viewer&quot;&gt;
#       &lt;!-- this is the canvas that will feature the brain slices --&gt;
#       &lt;canvas id=&quot;3Dviewer&quot;&gt;
#         &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#         &lt;img
#           id=&quot;spriteImg&quot;
#           class=&quot;hidden&quot;
#           src=&quot;data:image/png;base64,...&quot;
#           alt=&quot;background&quot;
#         /&gt;
#         &lt;!-- the colormap --&gt;
#         &lt;img
#           id=&quot;colorMap&quot;
#           class=&quot;hidden&quot;
#           src=&quot;...&quot;
#           alt=&quot;colormap&quot;
#         /&gt;
#         &lt;!-- another sprite image, with an overlay--&gt;
#         &lt;img
#           id=&quot;overlayImg&quot;
#           class=&quot;hidden&quot;
#           src=&quot;data:image/png;base64,...&quot;
#           alt=&quot;overlay&quot;
#         /&gt;
#       &lt;/canvas&gt;
#     &lt;/div&gt;
#
#     &lt;script&gt;
#       /*! jQuery v3.6.0 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],r=Object.getPrototypeOf,s=t.slice,g=t.flat?function(e){return t.flat.call(e)}:function(e){return t.concat.apply([],e)},u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},x=function(e){return null!=e&amp;&amp;e===e.window},E=C.document,c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.6.0&quot;,S=function(e,t){return new S.fn.init(e,t)};function p(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}S.fn=S.prototype={jquery:f,constructor:S,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=S.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return S.each(this,e)},map:function(n){return this.pushStack(S.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(S.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(S.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},S.extend=S.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(S.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||S.isPlainObject(n)?n:{},i=!1,a[t]=S.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},S.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){b(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(p(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(p(Object(e))?S.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o ...

# %% [markdown]
# ### Visualizing the MRI volume
#
# The Haxby dataset also contains anatomical MRI, through which we can visualise the different brain structures.

# %%
# Anatomical MRI file
anat_filename = haxby_dataset.anat[0]

# Visualize the anatomical image
plotting.view_img(anat_filename, symmetric_cmap=False, cmap='Greys_r', colorbar=False)
# Out:
# <iframe srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#   &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;div_viewer&quot;&gt;
#       &lt;!-- this is the canvas that will feature the brain slices --&gt;
#       &lt;canvas id=&quot;3Dviewer&quot;&gt;
#         &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#         &lt;img
#           id=&quot;spriteImg&quot;
#           class=&quot;hidden&quot;
#           src=&quot;data:image/png;base64,...&quot;
#           alt=&quot;background&quot;
#         /&gt;
#         &lt;!-- the colormap --&gt;
#         &lt;img
#           id=&quot;colorMap&quot;
#           class=&quot;hidden&quot;
#           src=&quot;data:image/png;base64,&quot;
#           alt=&quot;colormap&quot;
#         /&gt;
#         &lt;!-- another sprite image, with an overlay--&gt;
#         &lt;img
#           id=&quot;overlayImg&quot;
#           class=&quot;hidden&quot;
#           src=&quot;data:image/png;base64,...&quot;
#           alt=&quot;overlay&quot;
#         /&gt;
#       &lt;/canvas&gt;
#     &lt;/div&gt;
#
#     &lt;script&gt;
#       /*! jQuery v3.6.0 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],r=Object.getPrototypeOf,s=t.slice,g=t.flat?function(e){return t.flat.call(e)}:function(e){return t.concat.apply([],e)},u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType&amp;&amp;&quot;function&quot;!=typeof e.item},x=function(e){return null!=e&amp;&amp;e===e.window},E=C.document,c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.6.0&quot;,S=function(e,t){return new S.fn.init(e,t)};function p(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}S.fn=S.prototype={jquery:f,constructor:S,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=S.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return S.each(this,e)},map:function(n){return this.pushStack(S.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},even:function(){return this.pushStack(S.grep(this,function(e,t){return(t+1)%2}))},odd:function(){return this.pushStack(S.grep(this,function(e,t){return t%2}))},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},S.extend=S.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(S.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||S.isPlainObject(n)?n:{},i=!1,a[t]=S.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},S.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t,n){b(e,{nonce:t&amp;&amp;t.nonce},n)},each:function(e,t){var n,r=0;if(p(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(p(Object(e))?S.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o ...

# %% [markdown]
# ### Loading the mask
#
# These are some really lovely images, but for machine learning we need matrices to work with the actual data. If we want to use sklearn we will need to transform the Nifti images into a data matrix. For the first model we will only use voxels within Ventral Temporal (VT) cortex which is an visual processing area. A mask of the VT cortex coming from the Haxby study is available. We have to define a mask filename.

# %%
mask_filename = haxby_dataset.mask_vt[0]

# Let's visualize it, using the subject's anatomical image as a
# background
plotting.plot_roi(mask_filename, bg_img=haxby_dataset.anat[0], cmap="Paired")

print(mask_filename)
# Out:
# C:\Users\Gugu\nilearn_data\haxby2001\subj2\mask4_vt.nii.gz

# %% [markdown]
# ### Loading the labels
#
# Now we can load the labels that are stored in a CSV file, separated by spaces.
#
# We use pandas to load them in an array.

# %% [markdown]
# The task was a visual-recognition task, and the labels denote the experimental condition: the type of object that was presented to the subject. This is what we are going to try to predict.

# %%
import pandas as pd

# Load behavioral information
behavioral = pd.read_csv(haxby_dataset.session_target[0], delimiter=" ")

# Enable viewing of all rows of pandas dataframe
pd.set_option('display.max_rows', None)
print(behavioral)
# Out:
#             labels  chunks
# 0             rest       0
# 1             rest       0
# 2             rest       0
# 3             rest       0
# 4             rest       0
# 5             rest       0
# 6         scissors       0
# 7         scissors       0
# 8         scissors       0
# 9         scissors       0
# 10        scissors       0
# 11        scissors       0
# 12        scissors       0
# 13        scissors       0
# 14        scissors       0
# 15            rest       0
# 16            rest       0
# 17            rest       0
# 18            rest       0
# 19            rest       0
# 20            rest       0
# 21            face       0
# 22            face       0
# 23            face       0
# 24            face       0
# 25            face       0
# 26            face       0
# 27            face       0
# 28            face       0
# 29            face       0
# 30            rest       0
# 31            rest       0
# 32            rest       0
# 33            rest       0
# 34            rest       0
# 35             cat       0
# 36             cat       0
# 37             cat       0
# 38             cat       0
# 39             cat       0
# 40             cat       0
# 41             cat       0
# 42             cat       0
# 43             cat       0
# 44            rest       0
# 45            rest       0
# 46            rest       0
# 47            rest       0
# 48            rest       0
# 49            shoe       0
# 50            shoe       0
# 51            shoe       0
# 52            shoe       0
# 53            shoe       0
# 54            shoe       0
# 55            shoe       0
# 56            shoe       0
# 57            shoe       0
# 58            rest       0
# 59            rest       0
# 60            rest       0
# 61            rest       0
# 62            rest       0
# 63           house       0
# 64           house       0
# 65           house       0
# 66           house       0
# 67           house       0
# 68           house       0
# 69           house       0
# 70           house       0
# 71           house       0
# 72            rest       0
# 73            rest       0
# 74            rest       0
# 75            rest       0
# 76            rest       0
# 77            rest       0
# 78    scrambledpix       0
# 79    scrambledpix       0
# 80    scrambledpix       0
# 81    scrambledpix       0
# 82    scrambledpix       0
# 83    scrambledpix       0
# 84    scrambledpix       0
# 85    scrambledpix       0
# 86    scrambledpix       0
# 87            rest       0
# 88            rest       0
# 89            rest       0
# 90            rest       0
# 91            rest       0
# 92          bottle       0
# 93          bottle       0
# 94          bottle       0
# 95          bottle       0
# 96          bottle       0
# 97          bottle       0
# 98          bottle       0
# 99          bottle       0
# 100         bottle       0
# 101           rest       0
# 102           rest       0
# 103           rest       0
# 104           rest       0
# 105           rest       0
# 106          chair       0
# 107          chair       0
# 108          chair       0
# 109          chair       0
# 110          chair       0
# 111          chair       0
# 112          chair       0
# 113          chair       0
# 114          chair       0
# 115           rest       0
# 116           rest       0
# 117           rest       0
# 118           rest       0
# 119           rest       0
# 120           rest       0
# 121           rest       1
# 122           rest       1
# 123           rest       1
# 124           rest       1
# 125           rest       1
# 126           rest       1
# 127           face       1
# 128           face       1
# 129           face       1
# 130           face       1
# 131           face       1
# 132           face       1
# 133           face       1
# 134           face       1
# 135           face       1
# 136           rest       1
# 137           rest       1
# 138           rest       1
# 139           rest       1
# 140           rest       1
# 141           rest       1
# 142   scrambledpix       1
# 143   scrambledpix       1
# 144   scrambledpix       1
# 145   scrambledpix       1
# 146   scrambledpix       1
# 147   scrambledpix       1
# 148   scrambledpix       1
# 149   scrambledpix       1
# 150   scrambledpix       1
# 151           rest       1
# 152           rest       1
# 153           rest       1
# 154           rest       1
# 155           rest       1
# 156       scissors       1
# 157       scissors       1
# 158       scissors       1
# 159       scissors       1
# 160       scissors       1
# 161       scissors       1
# 162       scissors       1
# 163       scissors       1
# 164       scissors       1
# 165           rest       1
# 166           rest       1
# 167           rest       1
# 168           rest       1
# 169           rest       1
# 170           shoe       1
# 171           shoe       1
# 172           shoe       1
# 173           shoe       1
# 174           shoe       1
# 175           shoe       1
# 176           shoe       1
# 177           shoe       1
# 178           shoe       1
# 179           rest       1
# 180           rest       1
# 181           rest       1
# 182           rest       1
# 183           rest       1
# 184         bottle       1
# 185         bottle       1
# 186         bottle       1
# 187         bottle       1
# 188         bottle       1
# 189         bottle       1
# 190         bottle       1
# 191         bottle       1
# 192         bottle       1
# 193           rest       1
# 194           rest       1
# 195           rest       1
# 196           rest       1
# 197           rest       1
# 198           rest       1
# 199            cat       1
# 200            cat       1
# 201            cat       1
# 202            cat       1
# 203            cat       1
# 204            cat       1
# 205            cat       1
# 206            cat       1
# 207            cat       1
# 208           rest       1
# 209           rest       1
# 210           rest       1
# 211           rest       1
# 212           rest       1
# 213          chair       1
# 214          chair       1
# 215          chair       1
# 216          chair       1
# 217          chair       1
# 218          chair       1
# 219          chair       1
# 220          chair       1
# 221          chair       1
# 222           rest       1
# 223           rest       1
# 224           rest       1
# 225           rest       1
# 226           rest       1
# 227          house       1
# 228          house       1
# 229          house       1
# 230          house       1
# 231          house       1
# 232          house       1
# 233          house       1
# 234          house       1
# 235          house       1
# 236           rest       1
# 237           rest       1
# 238           rest       1
# 239           rest       1
# 240           rest       1
# 241           rest       1
# 242           rest       2
# 243           rest       2
# 244           rest       2
# 245           rest       2
# 246           rest       2
# 247           rest       2
# 248           face       2
# 249           face       2
# 250           face       2
# 251           face       2
# 252           face       2
# 253           face       2
# 254           face       2
# 255           face       2
# 256           face       2
# 257           rest       2
# 258           rest       2
# 259           rest       2
# 260           rest       2
# 261           rest       2
# 262           rest       2
# 263          chair       2
# 264          chair       2
# 265          chair       2
# 266          chair       2
# 267          chair       2
# 268          chair       2
# 269          chair       2
# 270          chair       2
# 271          chair       2
# 272           rest       2
# 273           rest       2
# 274           rest       2
# 275           rest       2
# 276           rest       2
# 277            cat       2
# 278            cat       2
# 279            cat       2
# 280            cat       2
# 281            cat       2
# 282            cat       2
# 283            cat       2
# 284            cat       2
# 285            cat       2
# 286           rest       2
# 287           rest       2
# 288           rest       2
# 289           rest       2
# 290           rest       2
# 291          house       2
# 292          house       2
# 293          house       2
# 294          house       2
# 295          house       2
# 296          house       2
# 297          house       2
# 298          house       2
# 299          house       2
# 300           rest       2
# 301           rest       2
# 302           rest       2
# 303           rest       2
# 304           rest       2
# 305   scrambledpix       2
# 306   scrambledpix       2
# 307   scrambledpix       2
# 308   scrambledpix       2
# 309   scrambledpix       2
# 310   scrambledpix       2
# 311   scrambledpix       2
# 312   scrambledpix       2
# 313   scrambledpix       2
# 314           rest       2
# 315           rest       2
# 316           rest       2
# 317           rest       2
# 318           rest       2
# 319           rest       2
# 320           shoe       2
# 321           shoe       2
# 322           shoe       2
# 323           shoe       2
# 324           shoe       2
# 325           shoe       2
# 326           shoe       2
# 327           shoe       2
# 328           shoe       2
# 329           rest       2
# 330           rest       2
# 331           rest       2
# 332           rest       2
# 333           rest       2
# 334         bottle       2
# 335         bottle       2
# 336         bottle       2
# 337         bottle       2
# 338         bottle       2
# 339         bottle       2
# 340         bottle       2
# 341         bottle       2
# 342         bottle       2
# 343           rest       2
# 344           rest       2
# 345           rest       2
# 346           rest       2
# 347           rest       2
# 348       scissors       2
# 349       scissors       2
# 350       scissors       2
# 351       scissors       2
# 352       scissors       2
# 353       scissors       2
# 354       scissors       2
# 355       scissors       2
# 356       scissors       2
# 357           rest       2
# 358           rest       2
# 359           rest       2
# 360           rest       2
# 361           rest       2
# 362           rest       2
# 363           rest       3
# 364           rest       3
# 365           rest       3
# 366           rest       3
# 367           rest       3
# 368           rest       3
# 369           shoe       3
# 370           shoe       3
# 371           shoe       3
# 372           shoe       3
# 373           shoe       3
# 374           shoe       3
# 375           shoe       3
# 376           shoe       3
# 377           shoe       3
# 378           rest       3
# 379           rest       3
# 380           rest       3
# 381           rest       3
# 382           rest       3
# 383           rest       3
# 384          house       3
# 385          house       3
# 386          house       3
# 387          house       3
# 388          house       3
# 389          house       3
# 390          house       3
# 391          house       3
# 392          house       3
# 393           rest       3
# 394           rest       3
# 395           rest       3
# 396           rest       3
# 397           rest       3
# 398          chair       3
# 399          chair       3
# 400          chair       3
# 401          chair       3
# 402          chair       3
# 403          chair       3
# 404          chair       3
# 405          chair       3
# 406          chair       3
# 407           rest       3
# 408           rest       3
# 409           rest       3
# 410           rest       3
# 411           rest       3
# 412            cat       3
# 413            cat       3
# 414            cat       3
# 415            cat       3
# 416            cat       3
# 417            cat       3
# 418            cat       3
# 419            cat       3
# 420            cat       3
# 421           rest       3
# 422           rest       3
# 423           rest       3
# 424           rest       3
# 425           rest       3
# 426           face       3
# 427           face       3
# 428           face       3
# 429           face       3
# 430           face       3
# 431           face       3
# 432           face       3
# 433           face       3
# 434           face       3
# 435           rest       3
# 436           rest       3
# 437           rest       3
# 438           rest       3
# 439           rest       3
# 440           rest       3
# 441   scrambledpix       3
# 442   scrambledpix       3
# 443   scrambledpix       3
# 444   scrambledpix       3
# 445   scrambledpix       3
# 446   scrambledpix       3
# 447   scrambledpix       3
# 448   scrambledpix       3
# 449   scrambledpix       3
# 450           rest       3
# 451           rest       3
# 452           rest       3
# 453           rest       3
# 454           rest       3
# 455         bottle       3
# 456         bottle       3
# 457         bottle       3
# 458         bottle       3
# 459         bottle       3
# 460         bottle       3
# 461         bottle       3
# 462         bottle       3
# 463         bottle       3
# 464           rest       3
# 465           rest       3
# 466           rest       3
# 467           rest       3
# 468           rest       3
# 469       scissors       3
# 470       scissors       3
# 471       scissors       3
# 472       scissors       3
# 473       scissors       3
# 474       scissors       3
# 475       scissors       3
# 476       scissors       3
# 477       scissors       3
# 478           rest       3
# 479           rest       3
# 480           rest       3
# 481           rest       3
# 482           rest       3
# 483           rest       3
# 484           rest       4
# 485           rest       4
# 486           rest       4
# 487           rest       4
# 488           rest       4
# 489           rest       4
# 490           face       4
# 491           face       4
# 492           face       4
# 493           face       4
# 494           face       4
# 495           face       4
# 496           face       4
# 497           face       4
# 498           face       4
# 499           rest       4
# 500           rest       4
# 501           rest       4
# 502           rest       4
# 503           rest       4
# 504           rest       4
# 505            cat       4
# 506            cat       4
# 507            cat       4
# 508            cat       4
# 509            cat       4
# 510            cat       4
# 511            cat       4
# 512            cat       4
# 513            cat       4
# 514           rest       4
# 515           rest       4
# 516           rest       4
# 517           rest       4
# 518           rest       4
# 519           shoe       4
# 520           shoe       4
# 521           shoe       4
# 522           shoe       4
# 523           shoe       4
# 524           shoe       4
# 525           shoe       4
# 526           shoe       4
# 527           shoe       4
# 528           rest       4
# 529           rest       4
# 530           rest       4
# 531           rest       4
# 532           rest       4
# 533          chair       4
# 534          chair       4
# 535          chair       4
# 536          chair       4
# 537          chair       4
# 538          chair       4
# 539          chair       4
# 540          chair       4
# 541          chair       4
# 542           rest       4
# 543           rest       4
# 544           rest       4
# 545           rest       4
# 546           rest       4
# 547       scissors       4
# 548       scissors       4
# 549       scissors       4
# 550       scissors       4
# 551       scissors       4
# 552       scissors       4
# 553       scissors       4
# 554       scissors       4
# 555       scissors       4
# 556           rest       4
# 557           rest       4
# 558           rest       4
# 559           rest       4
# 560           rest       4
# 561           rest       4
# 562         bottle       4
# 563         bottle       4
# 564         bottle       4
# 565         bottle       4
# 566         bottle       4
# 567         bottle       4
# 568         bottle       4
# 569         bottle       4
# 570         bottle       4
# 571           rest       4
# 572           rest       4
# 573           rest       4
# 574           rest       4
# 575           rest       4
# 576          house       4
# 577          house       4
# 578          house       4
# 579          house       4
# 580          house       4
# 581          house       4
# 582          house       4
# 583          house       4
# 584          house       4
# 585           rest       4
# 586           rest       4
# 587           rest       4
# 588           rest       4
# 589           rest       4
# 590   scrambledpix       4
# 591   scrambledpix       4
# 592   scrambledpix       4
# 593   scrambledpix       4
# 594   scrambledpix       4
# 595   scrambledpix       4
# 596   scrambledpix       4
# 597   scrambledpix       4
# 598   scrambledpix       4
# 599           rest       4
# 600           rest       4
# 601           rest       4
# 602           rest       4
# 603           rest       4
# 604           rest       4
# 605           rest       5
# 606           rest       5
# 607           rest       5
# 608           rest       5
# 609           rest       5
# 610           rest       5
# 611            cat       5
# 612            cat       5
# 613            cat       5
# 614            cat       5
# 615            cat       5
# 616            cat       5
# 617            cat       5
# 618            cat       5
# 619            cat       5
# 620           rest       5
# 621           rest       5
# 622           rest       5
# 623           rest       5
# 624           rest       5
# 625           rest       5
# 626   scrambledpix       5
# 627   scrambledpix       5
# 628   scrambledpix       5
# 629   scrambledpix       5
# 630   scrambledpix       5
# 631   scrambledpix       5
# 632   scrambledpix       5
# 633   scrambledpix       5
# 634   scrambledpix       5
# 635           rest       5
# 636           rest       5
# 637           rest       5
# 638           rest       5
# 639           rest       5
# 640       scissors       5
# 641       scissors       5
# 642       scissors       5
# 643       scissors       5
# 644       scissors       5
# 645       scissors       5
# 646       scissors       5
# 647       scissors       5
# 648       scissors       5
# 649           rest       5
# 650           rest       5
# 651           rest       5
# 652           rest       5
# 653           rest       5
# 654          chair       5
# 655          chair       5
# 656          chair       5
# 657          chair       5
# 658          chair       5
# 659          chair       5
# 660          chair       5
# 661          chair       5
# 662          chair       5
# 663           rest       5
# 664           rest       5
# 665           rest       5
# 666           rest       5
# 667           rest       5
# 668         bottle       5
# 669         bottle       5
# 670         bottle       5
# 671         bottle       5
# 672         bottle       5
# 673         bottle       5
# 674         bottle       5
# 675         bottle       5
# 676         bottle       5
# 677           rest       5
# 678           rest       5
# 679           rest       5
# 680           rest       5
# 681           rest       5
# 682           rest       5
# 683           shoe       5
# 684           shoe       5
# 685           shoe       5
# 686           shoe       5
# 687           shoe       5
# 688           shoe       5
# 689           shoe       5
# 690           shoe       5
# 691           shoe       5
# 692           rest       5
# 693           rest       5
# 694           rest       5
# 695           rest       5
# 696           rest       5
# 697           face       5
# 698           face       5
# 699           face       5
# 700           face       5
# 701           face       5
# 702           face       5
# 703           face       5
# 704           face       5
# 705           face       5
# 706           rest       5
# 707           rest       5
# 708           rest       5
# 709           rest       5
# 710           rest       5
# 711          house       5
# 712          house       5
# 713          house       5
# 714          house       5
# 715          house       5
# 716          house       5
# 717          house       5
# 718          house       5
# 719          house       5
# 720           rest       5
# 721           rest       5
# 722           rest       5
# 723           rest       5
# 724           rest       5
# 725           rest       5
# 726           rest       6
# 727           rest       6
# 728           rest       6
# 729           rest       6
# 730           rest       6
# 731           rest       6
# 732          house       6
# 733          house       6
# 734          house       6
# 735          house       6
# 736          house       6
# 737          house       6
# 738          house       6
# 739          house       6
# 740          house       6
# 741           rest       6
# 742           rest       6
# 743           rest       6
# 744           rest       6
# 745           rest       6
# 746           rest       6
# 747       scissors       6
# 748       scissors       6
# 749       scissors       6
# 750       scissors       6
# 751       scissors       6
# 752       scissors       6
# 753       scissors       6
# 754       scissors       6
# 755       scissors       6
# 756           rest       6
# 757           rest       6
# 758           rest       6
# 759           rest       6
# 760           rest       6
# 761         bottle       6
# 762         bottle       6
# 763         bottle       6
# 764         bottle       6
# 765         bottle       6
# 766         bottle       6
# 767         bottle       6
# 768         bottle       6
# 769         bottle       6
# 770           rest       6
# 771           rest       6
# 772           rest       6
# 773           rest       6
# 774           rest       6
# 775           face       6
# 776           face       6
# 777           face       6
# 778           face       6
# 779           face       6
# 780           face       6
# 781           face       6
# 782           face       6
# 783           face       6
# 784           rest       6
# 785           rest       6
# 786           rest       6
# 787           rest       6
# 788           rest       6
# 789          chair       6
# 790          chair       6
# 791          chair       6
# 792          chair       6
# 793          chair       6
# 794          chair       6
# 795          chair       6
# 796          chair       6
# 797          chair       6
# 798           rest       6
# 799           rest       6
# 800           rest       6
# 801           rest       6
# 802           rest       6
# 803           rest       6
# 804           shoe       6
# 805           shoe       6
# 806           shoe       6
# 807           shoe       6
# 808           shoe       6
# 809           shoe       6
# 810           shoe       6
# 811           shoe       6
# 812           shoe       6
# 813           rest       6
# 814           rest       6
# 815           rest       6
# 816           rest       6
# 817           rest       6
# 818            cat       6
# 819            cat       6
# 820            cat       6
# 821            cat       6
# 822            cat       6
# 823            cat       6
# 824            cat       6
# 825            cat       6
# 826            cat       6
# 827           rest       6
# 828           rest       6
# 829           rest       6
# 830           rest       6
# 831           rest       6
# 832   scrambledpix       6
# 833   scrambledpix       6
# 834   scrambledpix       6
# 835   scrambledpix       6
# 836   scrambledpix       6
# 837   scrambledpix       6
# 838   scrambledpix       6
# 839   scrambledpix       6
# 840   scrambledpix       6
# 841           rest       6
# 842           rest       6
# 843           rest       6
# 844           rest       6
# 845           rest       6
# 846           rest       6
# 847           rest       7
# 848           rest       7
# 849           rest       7
# 850           rest       7
# 851           rest       7
# 852           rest       7
# 853           face       7
# 854           face       7
# 855           face       7
# 856           face       7
# 857           face       7
# 858           face       7
# 859           face       7
# 860           face       7
# 861           face       7
# 862           rest       7
# 863           rest       7
# 864           rest       7
# 865           rest       7
# 866           rest       7
# 867           rest       7
# 868          chair       7
# 869          chair       7
# 870          chair       7
# 871          chair       7
# 872          chair       7
# 873          chair       7
# 874          chair       7
# 875          chair       7
# 876          chair       7
# 877           rest       7
# 878           rest       7
# 879           rest       7
# 880           rest       7
# 881           rest       7
# 882       scissors       7
# 883       scissors       7
# 884       scissors       7
# 885       scissors       7
# 886       scissors       7
# 887       scissors       7
# 888       scissors       7
# 889       scissors       7
# 890       scissors       7
# 891           rest       7
# 892           rest       7
# 893           rest       7
# 894           rest       7
# 895           rest       7
# 896           shoe       7
# 897           shoe       7
# 898           shoe       7
# 899           shoe       7
# 900           shoe       7
# 901           shoe       7
# 902           shoe       7
# 903           shoe       7
# 904           shoe       7
# 905           rest       7
# 906           rest       7
# 907           rest       7
# 908           rest       7
# 909           rest       7
# 910   scrambledpix       7
# 911   scrambledpix       7
# 912   scrambledpix       7
# 913   scrambledpix       7
# 914   scrambledpix       7
# 915   scrambledpix       7
# 916   scrambledpix       7
# 917   scrambledpix       7
# 918   scrambledpix       7
# 919           rest       7
# 920           rest       7
# 921           rest       7
# 922           rest       7
# 923           rest       7
# 924           rest       7
# 925          house       7
# 926          house       7
# 927          house       7
# 928          house       7
# 929          house       7
# 930          house       7
# 931          house       7
# 932          house       7
# 933          house       7
# 934           rest       7
# 935           rest       7
# 936           rest       7
# 937           rest       7
# 938           rest       7
# 939            cat       7
# 940            cat       7
# 941            cat       7
# 942            cat       7
# 943            cat       7
# 944            cat       7
# 945            cat       7
# 946            cat       7
# 947            cat       7
# 948           rest       7
# 949           rest       7
# 950           rest       7
# 951           rest       7
# 952           rest       7
# 953         bottle       7
# 954         bottle       7
# 955         bottle       7
# 956         bottle       7
# 957         bottle       7
# 958         bottle       7
# 959         bottle       7
# 960         bottle       7
# 961         bottle       7
# 962           rest       7
# 963           rest       7
# 964           rest       7
# 965           rest       7
# 966           rest       7
# 967           rest       7
# 968           rest       8
# 969           rest       8
# 970           rest       8
# 971           rest       8
# 972           rest       8
# 973           rest       8
# 974           face       8
# 975           face       8
# 976           face       8
# 977           face       8
# 978           face       8
# 979           face       8
# 980           face       8
# 981           face       8
# 982           face       8
# 983           rest       8
# 984           rest       8
# 985           rest       8
# 986           rest       8
# 987           rest       8
# 988           rest       8
# 989            cat       8
# 990            cat       8
# 991            cat       8
# 992            cat       8
# 993            cat       8
# 994            cat       8
# 995            cat       8
# 996            cat       8
# 997            cat       8
# 998           rest       8
# 999           rest       8
# 1000          rest       8
# 1001          rest       8
# 1002          rest       8
# 1003  scrambledpix       8
# 1004  scrambledpix       8
# 1005  scrambledpix       8
# 1006  scrambledpix       8
# 1007  scrambledpix       8
# 1008  scrambledpix       8
# 1009  scrambledpix       8
# 1010  scrambledpix       8
# 1011  scrambledpix       8
# 1012          rest       8
# 1013          rest       8
# 1014          rest       8
# 1015          rest       8
# 1016          rest       8
# 1017         house       8
# 1018         house       8
# 1019         house       8
# 1020         house       8
# 1021         house       8
# 1022         house       8
# 1023         house       8
# 1024         house       8
# 1025         house       8
# 1026          rest       8
# 1027          rest       8
# 1028          rest       8
# 1029          rest       8
# 1030          rest       8
# 1031      scissors       8
# 1032      scissors       8
# 1033      scissors       8
# 1034      scissors       8
# 1035      scissors       8
# 1036      scissors       8
# 1037      scissors       8
# 1038      scissors       8
# 1039      scissors       8
# 1040          rest       8
# 1041          rest       8
# 1042          rest       8
# 1043          rest       8
# 1044          rest       8
# 1045          rest       8
# 1046         chair       8
# 1047         chair       8
# 1048         chair       8
# 1049         chair       8
# 1050         chair       8
# 1051         chair       8
# 1052         chair       8
# 1053         chair       8
# 1054         chair       8
# 1055          rest       8
# 1056          rest       8
# 1057          rest       8
# 1058          rest       8
# 1059          rest       8
# 1060          shoe       8
# 1061          shoe       8
# 1062          shoe       8
# 1063          shoe       8
# 1064          shoe       8
# 1065          shoe       8
# 1066          shoe       8
# 1067          shoe       8
# 1068          shoe       8
# 1069          rest       8
# 1070          rest       8
# 1071          rest       8
# 1072          rest       8
# 1073          rest       8
# 1074        bottle       8
# 1075        bottle       8
# 1076        bottle       8
# 1077        bottle       8
# 1078        bottle       8
# 1079        bottle       8
# 1080        bottle       8
# 1081        bottle       8
# 1082        bottle       8
# 1083          rest       8
# 1084          rest       8
# 1085          rest       8
# 1086          rest       8
# 1087          rest       8
# 1088          rest       8
# 1089          rest       9
# 1090          rest       9
# 1091          rest       9
# 1387  scrambledpix      11
# 1388  scrambledpix      11
# 1389          rest      11
# 1390          rest      11
# 1391          rest      11
# 1392          rest      11
# 1393          rest      11
# 1394          face      11
# 1395          face      11
# 1396          face      11
# 1397          face      11
# 1398          face      11
# 1399          face      11
# 1400          face      11
# 1401          face      11
# 1402          face      11
# 1403          rest      11
# 1404          rest      11
# 1405          rest      11
# 1406          rest      11
# 1407          rest      11
# 1408          rest      11
# 1409          shoe      11
# 1410          shoe      11
# 1411          shoe      11
# 1412          shoe      11
# 1413          shoe      11
# 1414          shoe      11
# 1415          shoe      11
# 1416          shoe      11
# 1417          shoe      11
# 1418          rest      11
# 1419          rest      11
# 1420          rest      11
# 1421          rest      11
# 1422          rest      11
# 1423           cat      11
# 1424           cat      11
# 1425           cat      11
# 1426           cat      11
# 1427           cat      11
# 1428           cat      11
# 1429           cat      11
# 1430           cat      11
# 1431           cat      11
# 1432          rest      11
# 1433          rest      11
# 1434          rest      11
# 1435          rest      11
# 1436          rest      11
# 1437      scissors      11
# 1438      scissors      11
# 1439      scissors      11
# 1440      scissors      11
# 1441      scissors      11
# 1442      scissors      11
# 1443      scissors      11
# 1444      scissors      11
# 1445      scissors      11
# 1446          rest      11
# 1447          rest      11
# 1448          rest      11
# 1449          rest      11
# 1450          rest      11
# 1451          rest      11

# %% [markdown]
# As we can see from the targets above, the experiment contains many conditions. As a consequence, the data is quite big. Not all of this data has an interest to us for decoding, so we will keep only fMRI data corresponding to faces or houses. We create a mask of the samples belonging to these two conditions; this mask is then applied to the fMRI data to restrict the classification to the face vs house discrimination.
#
# The input data will become much smaller (i.e. fMRI data is shorter):

# %% [markdown]
# > How many time points correspond to our stimuli of interest?

# %%
from nilearn.image import index_img, smooth_img
import numpy as np

condition_mask = behavioral["labels"].isin(["face", "house"])
# The data is in one single large 4D image
fmri_niimgs = index_img(fmri_filename, condition_mask)

# Reading mask Nifti from filename path
fmri_niimgs_mask = smooth_img(mask_filename, None)


# Checking dimensionality of data
print(f'4D data dimensionality (3 spatial dimensions + time) {fmri_niimgs.shape}')
print(f'mask dimensionality {fmri_niimgs_mask.shape}')
# Out:
# 4D data dimensionality (3 spatial dimensions + time) (40, 64, 64, 216)
# mask dimensionality (40, 64, 64)

# %% [markdown]
# **Viewing the stimuli images**
#
# Now that we have selected a sample of labels (stimuli), we can visualise them.

# %%
import matplotlib.pyplot as plt
from nilearn.plotting import show

# Stimulus information from the Haxby dataset
stimulus_information = haxby_dataset.stimuli

# Filter the behavioral data using the same condition mask
filtered_behavioral = behavioral[condition_mask]

# Visualize stimuli corresponding to the filtered conditions
for stim_type in ["faces", "houses"]:  # Focus only on "face" and "house"
    file_names = stimulus_information[stim_type]

    # Align stimuli with the filtered behavioral data indices
    filtered_file_names = [
        file_names[i] for i in filtered_behavioral.index if i < len(file_names)
    ]

    # Display up to 16 stimuli images for the current type
    filtered_file_names = filtered_file_names[:16]
    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    fig.suptitle(f"Stimulus Type: {stim_type}", fontsize=16)

    for img_path, ax in zip(filtered_file_names, axes.ravel()):
        # Read and display the image
        img = plt.imread(img_path)
        ax.imshow(img, cmap=plt.cm.gray)

    # Turn off axes for all subplots
    for ax in axes.ravel():
        ax.axis("off")

    plt.tight_layout()
    plt.show()

show()

# %% [markdown]
# **Stimuli vs time plot**
# <br>Visualise the distribution of the two stimuli of interest during the experiment. Each point represents a particular label (face or house) that was shown at a particular time during the experiment. For each stimuli, an fMRI scan was acquired.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Use the filtered behavioral data
filtered_behavioral = behavioral[condition_mask]

# Create the scatter plot
ax = sns.scatterplot(
    x=filtered_behavioral.index,  # Time points (indices)
    y=filtered_behavioral["labels"],  # Labels ("face", "house")
    hue=filtered_behavioral["labels"],  # Color by label
    legend="full",  # Show legend for labels
    palette="colorblind"  # Use a colorblind-friendly palette
)

# Customize the plot
plt.title("Categories Shown Across Time (Filtered Data)")
ax.set_xlabel("Time point / fMRI scan")
ax.set_ylabel("Stimulus Category")
sns.despine(offset=5)  # Remove spines for a clean look

plt.show()

# %% [markdown]
# ### Converting the images into a data matrix and applying the mask

# %% [markdown]
# Reshape the data to prepare for a machine learning model i.e., get a data matrix in a 2D format: **features x samples**.

# %% [markdown]
# > Which dimension was flattened (spatial or temporal)? <br>

# %% [markdown]
# > What do the new dimensions correspond to?

# %%
# Convert the NIfTI image to a numpy array
data = fmri_niimgs.get_fdata()

# Reshape the data
# -1 will automatically calculate the size of the first dimension
reshaped_data = data.reshape(-1, data.shape[-1])

print(reshaped_data.shape)
# Out:
# (163840, 216)

# %% [markdown]
# Reshape the brain mask to match the new data shape

# %%
data_mask = fmri_niimgs_mask.get_fdata()
reshaped_mask = data_mask.reshape(-1)

print(reshaped_mask.shape)
# Out:
# (163840,)

# %% [markdown]
# **Count non-zero elements in the mask**
# <br>We use a brain mask to include only the part of the brain responsible for visual processing.

# %% [markdown]
# > How many data points does this leave us with in each fMRI scan, and how does this affect the number of features we will use in our model?

# %%
print(reshaped_mask.sum())
# Out:
# 464.0

# %% [markdown]
# **Sanity check**
# <br>Try reshaping the reshaped data and mask to the original shape

# %%
# reshaping to original

original_data_shape = (40, 64, 64, 216)  # Replace with the actual original shape
original_mask_shape = (40, 64, 64)

# Reshape data back to the original shape
data_original_shape = reshaped_data.reshape(original_data_shape)

# Reshape mask back to the original shape
mask_original_shape = reshaped_mask.reshape(original_mask_shape)

# %% [markdown]
# Check if the un-reshaped data and mask match the original

# %%
# check if original and un-reshape reshaped match
print(np.array_equal(data, data_original_shape))

# check if original and un-reshape reshaped match
print(np.array_equal(data_mask, mask_original_shape))
# Out:
# True
# True

# %% [markdown]
# **Filter the data**
# <br>Now that we have reshaped the data and brain mask, and checked them, we can apply the mask to our data to only include our brain region of interest (VT cortex).
# <br>We do this by keeping only the data elements that correspond to non-zero values in the mask.
# <br>We also create a matrix containing the position of the non-zero elements from the mask to keep track of the location of our brain regions of interest.

# %% [markdown]
# > What do you expect the resulting data shape to be?

# %%
# Apply the mask to the data
filtered_data = reshaped_data[reshaped_mask != 0]

# To get the index positions of the non-zero elements in the mask
# np.nonzero returns a tuple - take the first element
#  136287 136289 136348 136351 136416 136475 136479 136480 136539 136540
#  136542 136603 136606 136667 136733 136797 136926 140319 140320 140382
#  140383 140384 140385 140446 140510 140511 140512 140574 140575 140638
#  140700 140702 140765 140829 140892 141022 141086 144543 144544 144671
#  144795 144859 145052 145117]

# %% [markdown]
# We apply the same condition mask that we applied to the fMRI data earlier to the targets (i.e., get only targets corresponding to "house" or "face").
# <br>This is not the brain mask, but the `condition_mask` used to select our desired labels.

# %%
conditions = behavioral["labels"][condition_mask]
# Convert to numpy array
conditions = conditions.values
print(conditions.shape)
print(conditions)
# Out:
# (216,)
# ['face' 'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face' 'house'
#  'house' 'house' 'house' 'house' 'house' 'house' 'house' 'house' 'face'
#  'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face' 'house' 'house'
#  'house' 'house' 'house' 'house' 'house' 'house' 'house' 'face' 'face'
#  'face' 'face' 'face' 'face' 'face' 'face' 'face' 'house' 'house' 'house'
#  'house' 'house' 'house' 'house' 'house' 'house' 'house' 'house' 'house'
#  'house' 'house' 'house' 'house' 'house' 'house' 'face' 'face' 'face'
#  'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face'
#  'face' 'face' 'face' 'face' 'face' 'house' 'house' 'house' 'house'
#  'house' 'house' 'house' 'house' 'house' 'face' 'face' 'face' 'face'
#  'face' 'face' 'face' 'face' 'face' 'house' 'house' 'house' 'house'
#  'house' 'house' 'house' 'house' 'house' 'house' 'house' 'house' 'house'
#  'house' 'house' 'house' 'house' 'house' 'face' 'face' 'face' 'face'
#  'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face'
#  'face' 'face' 'face' 'face' 'house' 'house' 'house' 'house' 'house'
#  'house' 'house' 'house' 'house' 'face' 'face' 'face' 'face' 'face' 'face'
#  'face' 'face' 'face' 'house' 'house' 'house' 'house' 'house' 'house'
#  'house' 'house' 'house' 'house' 'house' 'house' 'house' 'house' 'house'
#  'house' 'house' 'house' 'face' 'face' 'face' 'face' 'face' 'face' 'face'
#  'face' 'face' 'house' 'house' 'house' 'house' 'house' 'house' 'house'
#  'house' 'house' 'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face'
#  'face' 'house' 'house' 'house' 'house' 'house' 'house' 'house' 'house'
#  'house' 'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face' 'face']

# %% [markdown]
# **Encode the labels**
# <br>Right now, the labels are in string format i.e., 'houses', 'faces'. To make them suitable for a ML task, we need to convert them to numerical values.
# <br>**Task:** create a vector of binary labels (`y`).

# %%
# add code to convert conditions to binary labels y

from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder()
encoded = ohe.fit_transform(conditions.reshape(-1,1))
categories = ohe.categories_[0]
categories
y = encoded
# Example: convert 'face' to 1 and 'house' to 0
# y = # Your code here...

# %% [markdown]
# Check your data shape.

# %%
print(filtered_data.shape)
print(y.shape)
# Out:
# (464, 216)
# (216, 2)

# %% [markdown]
# # 🧑‍💻 TASK 1: Train an SVM to decode the labels from the fMRI data

# %% [markdown]
# ## 1.1 Split the `filtered_data` into train and test (leaving the last 30 examples for test)

# %% [markdown]
# Create train and test sets for the classification model.

# %% [markdown]
# > How is the balance between features (p) and samples (N)?

# %%
# The number of features is the first dimension of filtered_data, and the number of samples is the second dimension
num_samples = filtered_data.shape[1]

# Calculate the index to split the dataset
split_index = 30  # Reserve the last 30 samples for testing

# Split the data along the second dimension
X_train, X_test = filtered_data[:, :split_index], filtered_data[:, split_index:]
y_train, y_test = y[:split_index, :], y[split_index:, :]

# Transpose X_train and X_test so that each row represents a sample
# Data shape will be (samples x features)
X_train = X_train.T
X_test = X_test.T

# Confirm the dimensions
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (30, 464)
# y_train shape: (30, 2)
# X_test shape: (186, 464)
# y_test shape: (186, 2)

# %% [markdown]
# ## 1.2 Do a **cross-validation** on the training set to optimize the SVM hyper-parameters and after apply the SVM model with the optimal hyper-parameter to the test data. Print the mean and the standard deviation of the CV score, the best hyperparameter and the test score

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import time

param_grid = {
    'C': [1, 2, 5, 10],  # Example values
    'gamma': [0.001, 0.01, 0.1],
    'kernel': ['rbf', 'linear']
}

# Create a GridSearchCV object with an SVM classifier
grid = GridSearchCV(SVC(), param_grid)  # 5-fold cross-validation

# Time the grid search
start_time = time.time()

# Perform grid search
grid.fit(X_train, y_train)

# Measure and print the time taken
time_taken = time.time() - start_time
print("Time taken for GridSearchCV with regular kernels: {:.2f} seconds".format(time_taken))


# Print the results
print("Mean CV Score: ", grid.cv_results_['mean_test_score'][grid.best_index_])
print("Std Dev of CV Score: ", grid.cv_results_['std_test_score'][grid.best_index_])
print("Best Hyperparameters: ", grid.best_params_)

# Evaluate on the test set
y_pred = grid.fit(X_train, y_train)
test_score = accuracy_score(y_test, y_pred)
print("Test Score: ", test_score)


# Predict on the test set
y_pred = grid.fit(X_test, y_test)

# Print predictions
print("Predictions on the test set:", y_pred)

# Calculate and print the accuracy score
test_accuracy = accuracy_score(y_test, y_pred)
print("Final Test Accuracy:", test_accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 19
#      16 start_time = time.time()
#      18 # Perform grid search
# ---> 19 grid.fit(X_train, y_train)
#      21 # Measure and print the time taken
#      22 time_taken = time.time() - start_time
#
# File c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:996, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     989 elif len(out) != n_candidates * n_splits:
#     990     raise ValueError(
#     991         "cv.split and cv.get_n_splits returned "
#     992         "inconsistent results. Expected {} "
#     993         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     994     )
# --> 996 _warn_or_raise_about_fit_failures(out, self.error_score)
#     998 # For callable self.scoring, the return type is only know after
#     999 # calling. If the return type is a dictionary, the error scores
#    1000 # can now be inserted with the correct key. The type checking
#    1001 # of out will be done in `_insert_error_scores`.
#    1002 if callable(self.scoring):
#
# File c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:529, in _warn_or_raise_about_fit_failures(results, error_score)
#     522 if num_failed_fits == num_fits:
#     523     all_fits_failed_message = (
#     524         f"\nAll the {num_fits} fits failed.\n"
#     525         "It is very likely that your model is misconfigured.\n"
#     526         "You can try to debug the error by setting error_score='raise'.\n\n"
#     527         f"Below are more details about the failures:\n{fit_errors_summary}"
#     528     )
# --> 529     raise ValueError(all_fits_failed_message)
#     531 else:
#     532     some_fits_failed_message = (
#     533         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     534         "The score on these train-test partitions for these parameters"
#    (...)
#     538         f"Below are more details about the failures:\n{fit_errors_summary}"
#     539     )
#
# ValueError:
# All the 120 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_base.py", line 190, in fit
#     X, y = self._validate_data(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 650, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py", line 1318, in check_X_y
#     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py", line 1339, in _check_y
#     y = column_or_1d(y, warn=True)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py", line 1381, in column_or_1d
#     y = check_array(
#         ^^^^^^^^^^^^
#   File "c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py", line 971, in check_array
#     array = _ensure_sparse_format(
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gugu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py", line 595, in _ensure_sparse_format
#     raise TypeError(
# TypeError: Sparse data was passed for y, but dense data is required. Use '.toarray()' to convert to a dense numpy array.

# %% [markdown]
# ## 1.3 Inspect the SVM weights
#
# Let's inspect and display the SVC model' weights by turning them into a nifti image.
#
# First we want to retrieve the SVM weights.

# %%
# add the code here to show the coefficients

# Make sure your best model is using a linear kernel
print("kernel:", grid.best_params_['kernel'])

# If the kernel is linear, retrieve the weights
if grid.None == 'linear':
    # The best estimator in your grid search
    best_svm = grid.None

    # Retrieve the SVM weights (coefficients)
    svm_weights = best_svm.None

    # Print the weights
    print("SVM Weights:", svm_weights)
else:
    print("SVM weights are not interpretable for non-linear kernels.")

# %% [markdown]
# It’s an array with only one coefficient per voxel (data point).

# %%
# add code to print the coef. shape
print("Shape of SVM Coefficients:", svm_weights.shape)

# %% [markdown]
# To get the Nifti image of these coefficients we need to convert the coef. to 3D and create a Nifti image

# %%
print(type(data_mask))

# %%
# add code here

from nilearn.image import new_img_like

# Initialize a 3D array with zeros
# Assume original_shape is the shape of the original 3D brain image
coef_3d = coef_3d = np.None

# Map the coefficients back to their original voxel locations
coef_3d.flat[nonzero_indices] = svm_weights

print(coef_3d.shape)


# Create a Nifti image
coef_img = new_img_like(fmri_niimgs_mask, coef_3d)

# coef_img is now a Nifti image of the SVM coefficients

# %% [markdown]
# ## 1.4 Plotting the SVM weights
# We can plot the weights, using the subject’s anatomical MRI as a background.

# %%
from nilearn import plotting

# Assuming coef_img is the Nifti image containing your SVM weights
# and haxby_dataset.anat[0] is the path to the anatomical image

# Plot the SVM weights
plotting.plot_stat_map(coef_img, bg_img=haxby_dataset.anat[0],
                       display_mode='ortho',
                       title='SVM Weights',
                       cut_coords=(28, -34, -22),
                       cmap='coolwarm')

# Show the plot
plotting.show()

# %% [markdown]
# # 👩‍💻 TASK 2: Train an SVM with pre-computed kernel for computational efficiency
#
# For the second task we will use the **whole brain** voxels as features. We will start by creating a whole brain mask to include all voxels within the brain.

# %%
from nilearn.maskers import NiftiMasker
from nilearn.plotting import plot_epi, plot_roi, show

masker = NiftiMasker(mask_strategy="epi")
masker.fit(fmri_filename)

whole_brain_mask = masker.mask_img_

# Let's visualize the whole brain mask, using the subject's anatomical image as a
# background
plotting.plot_roi(whole_brain_mask, bg_img=haxby_dataset.anat[0], cmap="Paired")

# Checking dimensionality of the mask
print(f'Mask dimensionality {whole_brain_mask.shape}')

# %% [markdown]
# Reshape whole brain mask

# %%
# Convert the NIfTI image to a numpy array
wb_mask = whole_brain_mask.get_fdata()
reshaped_wb_mask = wb_mask.reshape(None)

# Reshape the data
print(reshaped_wb_mask.shape)

# print(reshaped_whole_brain_mask.shape)

# %% [markdown]
# **Size of whole brain mask**
#
# Count non-zero elements in the new mask, which corresponds to the number of voxels within the whole brain mask

# %% [markdown]
# > How many data points are in the mask now? Compare this to the size of the VT mask used before.

# %%
print(reshaped_wb_mask.None)

# %% [markdown]
# Now, filter the data using the mask to keep only the brain.

# %%
# Apply the whole mask to the data
filtered_wb_data = reshaped_data[None]

# To get the index positions of the non-zero elements in the mask
# np.nonzero returns a tuple - take the first element
nonzero_wb_indices = np.None

# Now, 'filtered_data' contains only the rows with non-zero mask elements
# and 'nonzero_indices' contains the indices of these non-zero elements

# If you need an index matrix with the same shape as the filtered_matrix
# where each row is filled with the corresponding index from nonzero_indices
index_wb_matrix = np.tile(nonzero_indices[:, np.newaxis], (1, filtered_wb_data.shape[1]))

print(filtered_wb_data.shape)

# %% [markdown]
# Now we can create a data matrix using the whole brain mask and compute linear kernel from the data matrix $K = X'X$, and will repeat task 1 training the SVM using the option of a **pre-computed kernel**.
#
# https://scikit-learn.org/stable/auto_examples/svm/plot_custom_kernel.html#sphx-glr-auto-examples-svm-plot-custom-kernel-py

# %% [markdown]
# ## 2.1 Set up test/train split like in task 1

# %% [markdown]
# > How do the number of features (p) compare to the sample size (N) here?

# %%
# The number of features is the first dimension of filtered_data, and the number of samples is the second dimension
num_samples = filtered_wb_data.shape[1]

# Calculate the index to split the dataset
split_index = num_samples - 30  # Reserve the last 30 samples for testing

# Split the data along the second dimension
X_train, X_test = filtered_wb_data[:, :split_index], filtered_wb_data[:, split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Transpose X_train and X_test so that each row represents a sample
X_train = None
X_test = None

# Confirm the dimensions
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)

# %% [markdown]
# Apply a **linear kernel** to your data.

# %% [markdown]
# > What is the resulting data dimensionality after the kernel trick?

# %% [markdown]
# > How does it compare to the original data?

# %%
def linear_kernel(X,Y):
#     print(X.shape,Y.shape)
#     M = np.array([[2, 0], [0, 1.0]])
    return None

X_train_kernel = linear_kernel(None)
X_test_kernel = linear_kernel(None)

# Check the kernel and the data dimensionality
print("X_train_kernel shape:", X_train_kernel.shape)
print("X_train shape:", X_train.shape)
print("X_test_kernel shape:", X_test_kernel.shape)
print("X_test shape:", X_test.shape)

# %% [markdown]
# ## 2.3 Train SVM with precomputed Kernel on the entire original dataset ie `reshaped_data` rather than the masked reduced features dataset ie `filtered_data`

# %% [markdown]
# 🤔 What can we learn from the time differences of GridSearchCV using regular Kernels (task 1) vs a precomputed Kernel (task 2)?

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import time

# Define the parameter grid for hyperparameter tuning
param_grid_precomputed = {
    'C': [0.1, 1, 10, 100],  # Example values
    #    'gamma': [1, 0.1, 0.01, 0.001], # Do we need gamma? No since it's hyperparameter for certain kernel function like RBF
     'kernel': ['precomputed']
}

# Create a GridSearchCV object for the precomputed kernel
grid_precomputed = GridSearchCV(SVC(), param_grid_precomputed, refit=True, verbose=2, cv=5)

# Time the grid search for the precomputed kernel
start_time_precomputed = time.time()

# Perform grid search
grid_precomputed.None

# Measure and print the time taken
time_taken_precomputed = time.time() - start_time_precomputed
print("Time taken for GridSearchCV with precomputed kernel: {:.2f} seconds".format(time_taken_precomputed))


# Print the results
print("Mean CV Score: ", grid_precomputed.cv_results_['mean_test_score'][grid.best_index_])
print("Std Dev of CV Score: ", grid_precomputed.cv_results_['std_test_score'][grid.best_index_])
print("Best Hyperparameters: ", grid_precomputed.best_params_)

# Evaluate on the test set

y_pred = grid_precomputed.predict(X_test_kernel)
test_score = accuracy_score(y_test, y_pred)
print("Test Score: ", test_score)

# %% [markdown]
# # Mapping the dual weights back to the primal
#
# In order to visualize the weights in the input space we need to **map the SVM dual coefficients back to the primal weights**.

# %%
# Add code here
best_svm = grid_precomputed.None

# Retrieve the SVM weights (coefficients)
support_index = best_svm.support_
svm_alpha = best_svm.None

# %% [markdown]
# Compute the primal weights from the dual coefficients: a weighted sum of the support vectors.

# %%
precomputed_svm_weight = np.zeros(X_train.shape[1])
for i in range(len(support_index)):
    precomputed_svm_weight += X_train[support_index[i]]*svm_alpha[0][i]

# %% [markdown]
# Check the size of the resulting weights.

# %% [markdown]
# > What weight vector size do you expect?

# %%
precomputed_svm_weight.shape

# %% [markdown]
# Once we have the primal weights we can now create a nifti image using the same procedure as before

# %%
# Add code here

from nilearn.image import new_img_like

# Initialize a 3D array with zeros
# Assume original_shape is the shape of the original 3D brain image
coef_3d = coef_3d = np.None

# Map the coefficients back to their original voxel locations
coef_3d.flat[None] = precomputed_svm_weight

# print(coef_3d.shape)


# Create a Nifti image
coef_img = new_img_like(fmri_niimgs_mask, coef_3d)

# coef_img is now a Nifti image of the SVM coefficients

# %%
# add code here
from nilearn import plotting

# Assuming coef_img is the Nifti image containing your SVM weights
# and haxby_dataset.anat[0] is the path to the anatomical image

# Plot the SVM weights
plotting.plot_stat_map(coef_img, bg_img=haxby_dataset.anat[0],
                       display_mode='ortho',
                       title='SVM Weights',
                       cut_coords=(28, -34, -22),
                       cmap='coolwarm')

# Show the plot
plotting.show()
